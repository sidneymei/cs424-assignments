# %% [markdown]
# # Part 1: Loading, Profiling, & Cleaning
# Group: The Tree Friends

# %% [markdown]
# ## Task 0?: Environment Setup (Optional)
#
# Here, we are installing the Python packages and downloading the datasets required to ensure we have the necessary tools for our analysis.

# %% [markdown]
# ### Installing the Packages
#
# In the following cell, we're installing the necessary Python packages for this part of our analysis.

# %%
# %%capture

# %pip install requests
# %pip install pandas
# %pip install geopandas

# %% [markdown]
# ### Downloading the Data
#
# ![Image](https://magical-milk-bucket.nyc3.digitaloceanspaces.com/DataRetrieval_Screenshot.png)
# *The portion highlighted in yellow indicates the button for accessing the data. It presents options to download the appropriate files.*
#
# By exporting the data directly, we can access the comprehensive dataset from the City of Chicago, which consists of 770K rows and 49 columns, rather than the limited subset provided via the SODA API.

# %%
crashes_csv = 'Traffic_Crashes_-_Crashes.csv'
crashes_geojson = 'Traffic Crashes - Crashes.geojson'

# %% [markdown]
# The aforementioned filenames correspond to the files we'll be downloading in the next step, which will be integral to our analysis moving forward. We'll use a CSV for Pandas, as it's often more compact and efficient than JSON for large datasets.

# %% [markdown]
# The following function checks if the file exists locally. If not, it streams the download in chunks, ensuring efficiency, especially for larger files.
#
# Please note, the duration may vary based on the speed of your internet connection.

# %%
import os
import requests

def download_data(url: str, fn: str = None) -> None:
    '''
    Downloads the file from specified link if it doesn't exist already.
    '''

    if fn is None:
        fn = url.split("/")[-1]

    if os.path.exists(fn):
        return

    with requests.get(url, stream=True) as r:
        r.raise_for_status() # Throw an error if an issue arises
        with open(fn, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192):
                f.write(chunk)

# %%
# base_url = 'https://data.cityofchicago.org/api'

# download_data(f'{base_url}/views/85ca-t3if/rows.json?accessType=DOWNLOAD', crashes_csv)
# download_data(f'{base_url}/geospatial/85ca-t3if?accessType=DOWNLOAD&method=export&format=GeoJSON', crashes_geojson)

# %% [markdown]
# When downloaded from the aforementioned endpoints, we can obtain the most recent versions of the dataset. Nonetheless, given intermittent access issues in Google Colab, we've chosen to store these files on the cloud. This not only provides a static version of the files but also serves as a reliable backup.

# %%
base_url = 'https://magical-milk-bucket.nyc3.digitaloceanspaces.com'

download_data(f'{base_url}/{crashes_csv}')
download_data(f'{base_url}/{crashes_geojson}')

# %% [markdown]
# ## Task 1 - Data Importation & Transformation
#
# Now since we have the dataset, we'll load it, get an initial understanding of its attributes, and perform the necessary transformations.

# %%
import pandas as pd

df = pd.read_csv(crashes_csv)

df.head().T # Transpose the table for a better view of the columns
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                000ececd00a4474d1abebf13221e4a97efd79a0322f117...
# RD_NO                                                                   JG360767
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                07/29/2023 11:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      07/29/2023 11:43:00 AM
# PRIM_CONTRIBUTORY_CAUSE                            FAILING TO YIELD RIGHT-OF-WAY
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                    804
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           KEDZIE AVE
# BEAT_OF_OCCURRENCE                                                        1121.0
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    11
# CRASH_DAY_OF_WEEK                                                              7
# CRASH_MONTH                                                                    7
# LATITUDE                                                               41.895745
# LONGITUDE                                                              -87.70671
# LOCATION                                POINT (-87.706709567706 41.895744504664)
#
#                                                                                1  \
# CRASH_RECORD_ID                00e20a26e53d0c6806fdb89244115fc27bdb3b368e1d03...
# RD_NO                                                                   JG434999
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                09/22/2023 06:00:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                          ONE-WAY
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/22/2023 06:50:00 PM
# PRIM_CONTRIBUTORY_CAUSE                   FAILING TO REDUCE SPEED TO AVOID CRASH
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   3856
# STREET_DIRECTION                                                               S
# STREET_NAME                                                             WELLS ST
# BEAT_OF_OCCURRENCE                                                         915.0
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    18
# CRASH_DAY_OF_WEEK                                                              6
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.823938
# LONGITUDE                                                             -87.632617
# LOCATION                                POINT (-87.632617158418 41.823938255628)
#
#                                                                                2  \
# CRASH_RECORD_ID                018bf30065a8947fb73e947c0bd197536d746d60b49eb3...
# RD_NO                                                                   JG412388
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                09/05/2023 03:54:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                                   UNKNOWN
# DEVICE_CONDITION                                                         UNKNOWN
# WEATHER_CONDITION                                                        UNKNOWN
# LIGHTING_CONDITION                                                       UNKNOWN
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                          UNKNOWN
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                     UNKNOWN
# ROAD_DEFECT                                                              UNKNOWN
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                  Y
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2023 04:45:00 PM
# PRIM_CONTRIBUTORY_CAUSE                                      UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   2317
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           CICERO AVE
# BEAT_OF_OCCURRENCE                                                        2522.0
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    15
# CRASH_DAY_OF_WEEK                                                              3
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.922931
# LONGITUDE                                                             -87.746119
# LOCATION                                POINT (-87.746119477943 41.922931042554)
#
#                                                                                3  \
# CRASH_RECORD_ID                01ddd522eb074a6cbec117c10de0cae2cb78d2a6dd94b2...
# RD_NO                                                                   JG412232
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                09/05/2023 01:33:00 PM
# POSTED_SPEED_LIMIT                                                            35
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                        SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                                  DIVIDED - W/MEDIAN (NOT RAISED)
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                             $501 - $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2023 01:33:00 PM
# PRIM_CONTRIBUTORY_CAUSE                            FAILING TO YIELD RIGHT-OF-WAY
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                  10112
# STREET_DIRECTION                                                               S
# STREET_NAME                                                     INDIANAPOLIS AVE
# BEAT_OF_OCCURRENCE                                                         432.0
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    13
# CRASH_DAY_OF_WEEK                                                              3
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.711641
# LONGITUDE                                                             -87.534202
# LOCATION                                POINT (-87.534201556839 41.711641416553)
#
#                                                                                4
# CRASH_RECORD_ID                01eb75485f6215d7b60bc219666c21564ac2ce46c578fb...
# RD_NO                                                                   JG412428
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE                                                09/05/2023 02:59:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                  DIVIDED - W/MEDIAN (NOT RAISED)
# LANE_CNT                                                                     NaN
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                              $500 OR LESS
# DATE_POLICE_NOTIFIED                                      09/05/2023 05:10:00 PM
# PRIM_CONTRIBUTORY_CAUSE                   FAILING TO REDUCE SPEED TO AVOID CRASH
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   2612
# STREET_DIRECTION                                                               S
# STREET_NAME                                                           KEDZIE AVE
# BEAT_OF_OCCURRENCE                                                        1032.0
# PHOTOS_TAKEN_I                                                               NaN
# STATEMENTS_TAKEN_I                                                           NaN
# DOORING_I                                                                    NaN
# WORK_ZONE_I                                                                  NaN
# WORK_ZONE_TYPE                                                               NaN
# WORKERS_PRESENT_I                                                            NaN
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              3
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.844085
# LONGITUDE                                                             -87.705177
# LOCATION                                POINT (-87.705176886078 41.844084644336)

# %% [markdown]
# By performing `head()`, we can get a generalized idea of how our dataset looks. Similarly, we'll perform the same for the `GeoDataFrame`.

# %%
import geopandas as gpd

gdf = gpd.read_file(crashes_geojson)

gdf.head().T
# Out:
#                                                                                0  \
# work_zone_type                                                               NaN
# injuries_fatal                                                                 0
# workers_present_i                                                            NaN
# injuries_non_incapacitating                                                    0
# crash_record_id                198f8e0a5a47a1ccf052708875c54d14ae50aedc5c1427...
# injuries_incapacitating                                                        0
# injuries_no_indication                                                         3
# latitude                                                            41.953858398
# lighting_condition                                        DARKNESS, LIGHTED ROAD
# street_no                                                                   2825
# injuries_unknown                                                               0
# device_condition                                                     NO CONTROLS
# rd_no                                                                        NaN
# crash_date                                                   2023-10-07 23:51:00
# private_property_i                                                           NaN
# trafficway_type                                                      NOT DIVIDED
# traffic_control_device                                               NO CONTROLS
# road_defect                                                           NO DEFECTS
# damage                                                               OVER $1,500
# crash_date_est_i                                                             NaN
# longitude                                                          -87.699316732
# crash_month                                                                   10
# street_name                                                       IRVING PARK RD
# crash_day_of_week                                                              7
# crash_hour                                                                    23
# first_crash_type                                                        REAR END
# injuries_reported_not_evident                                                  0
# statements_taken_i                                                           NaN
# num_units                                                                      2
# most_severe_injury                                       NO INDICATION OF INJURY
# date_police_notified                                         2023-10-07 23:53:00
# photos_taken_i                                                               NaN
# weather_condition                                                          CLEAR
# prim_contributory_cause        OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELE...
# hit_and_run_i                                                                  Y
# report_type                                                             ON SCENE
# alignment                                                     STRAIGHT AND LEVEL
# intersection_related_i                                                       NaN
# sec_contributory_cause                                            NOT APPLICABLE
# crash_type                                      INJURY AND / OR TOW DUE TO CRASH
# beat_of_occurrence                                                          1733
# street_direction                                                               W
# work_zone_i                                                                  NaN
# roadway_surface_cond                                                         DRY
# posted_speed_limit                                                            30
# injuries_total                                                                 0
# lane_cnt                                                                     NaN
# dooring_i                                                                    NaN
# geometry                                POINT (-87.699316732263 41.953858397876)
#
#                                                                                1  \
# work_zone_type                                                               NaN
# injuries_fatal                                                                 0
# workers_present_i                                                            NaN
# injuries_non_incapacitating                                                    1
# crash_record_id                a339c809696e7787e44b9a9b1711acb4db7360154e4f57...
# injuries_incapacitating                                                        0
# injuries_no_indication                                                         1
# latitude                                                            41.770569861
# lighting_condition                                        DARKNESS, LIGHTED ROAD
# street_no                                                                    733
# injuries_unknown                                                               0
# device_condition                                                     NO CONTROLS
# rd_no                                                                        NaN
# crash_date                                                   2023-10-07 23:35:00
# private_property_i                                                           NaN
# trafficway_type                                                      NOT DIVIDED
# traffic_control_device                                               NO CONTROLS
# road_defect                                                           NO DEFECTS
# damage                                                               OVER $1,500
# crash_date_est_i                                                             NaN
# longitude                                                          -87.643131336
# crash_month                                                                   10
# street_name                                                              68TH ST
# crash_day_of_week                                                              7
# crash_hour                                                                    23
# first_crash_type                                                      PEDESTRIAN
# injuries_reported_not_evident                                                  0
# statements_taken_i                                                           NaN
# num_units                                                                      2
# most_severe_injury                                      NONINCAPACITATING INJURY
# date_police_notified                                         2023-10-07 23:35:00
# photos_taken_i                                                               NaN
# weather_condition                                                          CLEAR
# prim_contributory_cause                                      UNABLE TO DETERMINE
# hit_and_run_i                                                                  Y
# report_type                                                             ON SCENE
# alignment                                                     STRAIGHT AND LEVEL
# intersection_related_i                                                       NaN
# sec_contributory_cause                                       UNABLE TO DETERMINE
# crash_type                                      INJURY AND / OR TOW DUE TO CRASH
# beat_of_occurrence                                                           723
# street_direction                                                               W
# work_zone_i                                                                  NaN
# roadway_surface_cond                                                         DRY
# posted_speed_limit                                                            30
# injuries_total                                                                 1
# lane_cnt                                                                     NaN
# dooring_i                                                                    NaN
# geometry                                POINT (-87.643131336416 41.770569861034)
#
#                                                                                2  \
# work_zone_type                                                               NaN
# injuries_fatal                                                                 0
# workers_present_i                                                            NaN
# injuries_non_incapacitating                                                    1
# crash_record_id                13edf825facf4eabbc8692711fd49ba492cdb18f1da5fe...
# injuries_incapacitating                                                        0
# injuries_no_indication                                                         0
# latitude                                                            41.960065664
# lighting_condition                                        DARKNESS, LIGHTED ROAD
# street_no                                                                   4251
# injuries_unknown                                                               0
# device_condition                                                         UNKNOWN
# rd_no                                                                        NaN
# crash_date                                                   2023-10-07 22:41:00
# private_property_i                                                           NaN
# trafficway_type                                       DIVIDED - W/MEDIAN BARRIER
# traffic_control_device                                               NO CONTROLS
# road_defect                                                           NO DEFECTS
# damage                                                               OVER $1,500
# crash_date_est_i                                                             NaN
# longitude                                                          -87.645933216
# crash_month                                                                   10
# street_name                                                     LAKE SHORE DR SB
# crash_day_of_week                                                              7
# crash_hour                                                                    22
# first_crash_type                                                    FIXED OBJECT
# injuries_reported_not_evident                                                  0
# statements_taken_i                                                           NaN
# num_units                                                                      1
# most_severe_injury                                      NONINCAPACITATING INJURY
# date_police_notified                                         2023-10-07 22:41:00
# photos_taken_i                                                               NaN
# weather_condition                                                          CLEAR
# prim_contributory_cause                                      UNABLE TO DETERMINE
# hit_and_run_i                                                                NaN
# report_type                                                             ON SCENE
# alignment                                                     STRAIGHT AND LEVEL
# intersection_related_i                                                       NaN
# sec_contributory_cause                                       UNABLE TO DETERMINE
# crash_type                                      INJURY AND / OR TOW DUE TO CRASH
# beat_of_occurrence                                                          1915
# street_direction                                                               N
# work_zone_i                                                                  NaN
# roadway_surface_cond                                                         DRY
# posted_speed_limit                                                            45
# injuries_total                                                                 1
# lane_cnt                                                                     NaN
# dooring_i                                                                    NaN
# geometry                                POINT (-87.645933216223 41.960065664234)
#
#                                                                                3  \
# work_zone_type                                                               NaN
# injuries_fatal                                                                 0
# workers_present_i                                                            NaN
# injuries_non_incapacitating                                                    0
# crash_record_id                8ad1109c818e291a195b914bfb9fce177ec8e0cd03c8ab...
# injuries_incapacitating                                                        0
# injuries_no_indication                                                         1
# latitude                                                            41.659076075
# lighting_condition                                                      DARKNESS
# street_no                                                                   2629
# injuries_unknown                                                               0
# device_condition                                            FUNCTIONING PROPERLY
# rd_no                                                                        NaN
# crash_date                                                   2023-10-07 21:25:00
# private_property_i                                                           NaN
# trafficway_type                                                   T-INTERSECTION
# traffic_control_device                                            TRAFFIC SIGNAL
# road_defect                                                           NO DEFECTS
# damage                                                               OVER $1,500
# crash_date_est_i                                                             NaN
# longitude                                                          -87.559364801
# crash_month                                                                   10
# street_name                                                             130TH ST
# crash_day_of_week                                                              7
# crash_hour                                                                    21
# first_crash_type                                                         TURNING
# injuries_reported_not_evident                                                  0
# statements_taken_i                                                           NaN
# num_units                                                                      3
# most_severe_injury                                       NO INDICATION OF INJURY
# date_police_notified                                         2023-10-07 21:40:00
# photos_taken_i                                                               NaN
# weather_condition                                                          CLEAR
# prim_contributory_cause                            FAILING TO YIELD RIGHT-OF-WAY
# hit_and_run_i                                                                  Y
# report_type                                                             ON SCENE
# alignment                                                     STRAIGHT AND LEVEL
# intersection_related_i                                                         Y
# sec_contributory_cause                                       UNABLE TO DETERMINE
# crash_type                                      INJURY AND / OR TOW DUE TO CRASH
# beat_of_occurrence                                                           434
# street_direction                                                               E
# work_zone_i                                                                  NaN
# roadway_surface_cond                                                         DRY
# posted_speed_limit                                                            30
# injuries_total                                                                 0
# lane_cnt                                                                     NaN
# dooring_i                                                                    NaN
# geometry                                POINT (-87.559364801272 41.659076074599)
#
#                                                                                4
# work_zone_type                                                               NaN
# injuries_fatal                                                                 0
# workers_present_i                                                            NaN
# injuries_non_incapacitating                                                    1
# crash_record_id                9aed1ff419292364a4520a876f88f587b0ef8c72a3c22b...
# injuries_incapacitating                                                        0
# injuries_no_indication                                                         4
# latitude                                                            42.011752805
# lighting_condition                                                      DARKNESS
# street_no                                                                   3199
# injuries_unknown                                                               0
# device_condition                                                     NO CONTROLS
# rd_no                                                                        NaN
# crash_date                                                   2023-10-07 21:15:00
# private_property_i                                                           NaN
# trafficway_type                                                         FOUR WAY
# traffic_control_device                                               NO CONTROLS
# road_defect                                                           NO DEFECTS
# damage                                                             $501 - $1,500
# crash_date_est_i                                                             NaN
# longitude                                                          -87.708942564
# crash_month                                                                   10
# street_name                                                            TOUHY AVE
# crash_day_of_week                                                              7
# crash_hour                                                                    21
# first_crash_type                                                           ANGLE
# injuries_reported_not_evident                                                  0
# statements_taken_i                                                           NaN
# num_units                                                                      3
# most_severe_injury                                      NONINCAPACITATING INJURY
# date_police_notified                                         2023-10-07 23:02:00
# photos_taken_i                                                               NaN
# weather_condition                                                          CLEAR
# prim_contributory_cause                   FAILING TO REDUCE SPEED TO AVOID CRASH
# hit_and_run_i                                                                NaN
# report_type                                                             ON SCENE
# alignment                                                     STRAIGHT AND LEVEL
# intersection_related_i                                                         Y
# sec_contributory_cause                                       UNABLE TO DETERMINE
# crash_type                                      INJURY AND / OR TOW DUE TO CRASH
# beat_of_occurrence                                                          2411
# street_direction                                                               W
# work_zone_i                                                                  NaN
# roadway_surface_cond                                                         DRY
# posted_speed_limit                                                            30
# injuries_total                                                                 1
# lane_cnt                                                                     NaN
# dooring_i                                                                    NaN
# geometry                                POINT (-87.708942564305 42.011752805351)

# %% [markdown]
# ### Profiling the Data
#
# From an initial glance, we can see that there are slight differences between the columns in each dataframe. We'll run some code to highlight them.

# %%
# Match the columns for consistency
df.columns = df.columns.str.lower()

# Running it twice as the difference is what isn't in the other
diff1 = df.columns.difference(gdf.columns).to_list()
diff2 = gdf.columns.difference(df.columns).to_list()

diff1, diff2
# Out:
# (['location', 'not_right_of_way_i'], ['geometry', 'private_property_i'])

# %% [markdown]
# They containg two differentiating column names; however, `LOCATION` and `geometry` are representative of the same coordinates as seen above.

# %% [markdown]
# Next, to get a general overview of each dataset, we'll:
#
# - Run `info()` to get details on the columns, memory usage, and more.
# - Identify the percentage of missing values for each attribute.
# - Calculate basic statistics for numerical columns with `describe()`.
# - Identify the unique categories for categorical columns.

# %%
from IPython.display import HTML
from io import StringIO

# We're using StringIO to store the information from both dataframes
# into memory so we're able to display them side-by-side later on.

buf1 = StringIO()
df.info(buf=buf1)
info_df = buf1.getvalue()

buf2 = StringIO()
gdf.info(buf=buf2)
info_gdf = buf2.getvalue()

display(HTML(f"""
<div style="float: left; width: 50%;"><pre>{info_df}</pre></div>
<div style="float: right; width: 50%;"><pre>{info_gdf}</pre></div>
"""))
# Out:
# <div style="float: left; width: 50%;"><pre><class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768535 entries, 0 to 768534
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   crash_record_id                768535 non-null  object
#  1   rd_no                          764137 non-null  object
#  2   crash_date_est_i               57852 non-null   object
#  3   crash_date                     768535 non-null  object
#  4   posted_speed_limit             768535 non-null  int64
#  5   traffic_control_device         768535 non-null  object
#  6   device_condition               768535 non-null  object
#  7   weather_condition              768535 non-null  object
#  8   lighting_condition             768535 non-null  object
#  9   first_crash_type               768535 non-null  object
#  10  trafficway_type                768535 non-null  object
#  11  lane_cnt                       199005 non-null  float64
#  12  alignment                      768535 non-null  object
#  13  roadway_surface_cond           768535 non-null  object
#  14  road_defect                    768535 non-null  object
#  15  report_type                    746368 non-null  object
#  16  crash_type                     768535 non-null  object
#  17  intersection_related_i         176052 non-null  object
#  18  not_right_of_way_i             35671 non-null   object
#  19  hit_and_run_i                  239960 non-null  object
#  20  damage                         768535 non-null  object
#  21  date_police_notified           768535 non-null  object
#  22  prim_contributory_cause        768535 non-null  object
#  23  sec_contributory_cause         768535 non-null  object
#  24  street_no                      768535 non-null  int64
#  25  street_direction               768531 non-null  object
#  26  street_name                    768534 non-null  object
#  27  beat_of_occurrence             768530 non-null  float64
#  28  photos_taken_i                 9896 non-null    object
#  29  statements_taken_i             16747 non-null   object
#  30  dooring_i                      2376 non-null    object
#  31  work_zone_i                    4450 non-null    object
#  32  work_zone_type                 3463 non-null    object
#  33  workers_present_i              1144 non-null    object
#  34  num_units                      768535 non-null  int64
#  35  most_severe_injury             766849 non-null  object
#  36  injuries_total                 766860 non-null  float64
#  37  injuries_fatal                 766860 non-null  float64
#  38  injuries_incapacitating        766860 non-null  float64
#  39  injuries_non_incapacitating    766860 non-null  float64
#  40  injuries_reported_not_evident  766860 non-null  float64
#  41  injuries_no_indication         766860 non-null  float64
#  42  injuries_unknown               766860 non-null  float64
#  43  crash_hour                     768535 non-null  int64
#  44  crash_day_of_week              768535 non-null  int64
#  45  crash_month                    768535 non-null  int64
#  46  latitude                       763426 non-null  float64
#  47  longitude                      763426 non-null  float64
#  48  location                       763426 non-null  object
# dtypes: float64(11), int64(6), object(32)
# memory usage: 287.3+ MB
# </pre></div>
# <div style="float: right; width: 50%;"><pre><class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 768535 entries, 0 to 768534
# Data columns (total 49 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   work_zone_type                 3463 non-null    object
#  1   injuries_fatal                 766860 non-null  object
#  2   workers_present_i              1144 non-null    object
#  3   injuries_non_incapacitating    766860 non-null  object
#  4   crash_record_id                768535 non-null  object
#  5   injuries_incapacitating        766860 non-null  object
#  6   injuries_no_indication         766860 non-null  object
#  7   latitude                       763426 non-null  object
#  8   lighting_condition             768535 non-null  object
#  9   street_no                      768535 non-null  object
#  10  injuries_unknown               766860 non-null  object
#  11  device_condition               768535 non-null  object
#  12  rd_no                          764137 non-null  object
#  13  crash_date                     768535 non-null  datetime64[ns]
#  14  private_property_i             35671 non-null   object
#  15  trafficway_type                768535 non-null  object
#  16  traffic_control_device         768535 non-null  object
#  17  road_defect                    768535 non-null  object
#  18  damage                         768535 non-null  object
#  19  crash_date_est_i               57852 non-null   object
#  20  longitude                      763426 non-null  object
#  21  crash_month                    768535 non-null  object
#  22  street_name                    768534 non-null  object
#  23  crash_day_of_week              768535 non-null  object
#  24  crash_hour                     768535 non-null  object
#  25  first_crash_type               768535 non-null  object
#  26  injuries_reported_not_evident  766860 non-null  object
#  27  statements_taken_i             16747 non-null   object
#  28  num_units                      768535 non-null  object
#  29  most_severe_injury             766849 non-null  object
#  30  date_police_notified           768535 non-null  datetime64[ns]
#  31  photos_taken_i                 9896 non-null    object
#  32  weather_condition              768535 non-null  object
#  33  prim_contributory_cause        768535 non-null  object
#  34  hit_and_run_i                  239960 non-null  object
#  35  report_type                    746368 non-null  object
#  36  alignment                      768535 non-null  object
#  37  intersection_related_i         176052 non-null  object
#  38  sec_contributory_cause         768535 non-null  object
#  39  crash_type                     768535 non-null  object
#  40  beat_of_occurrence             768530 non-null  object
#  41  street_direction               768531 non-null  object
#  42  work_zone_i                    4450 non-null    object
#  43  roadway_surface_cond           768535 non-null  object
#  44  posted_speed_limit             768535 non-null  object
#  45  injuries_total                 766860 non-null  object
#  46  lane_cnt                       199005 non-null  object
#  47  dooring_i                      2376 non-null    object
#  48  geometry                       763426 non-null  geometry
# dtypes: datetime64[ns](2), geometry(1), object(46)
# memory usage: 287.3+ MB
# </pre></div>

# %% [markdown]
# We note that both dataframes have an identical number of rows and columns as indicated, and they consume the same memory. Beyond these similarities, there are disparities in the data types used.

# %%
# Calculate the percentage of entries missing
df_missing_percentages = df.isna().mean() * 100
gdf_missing_percentages = gdf.isna().mean() * 100

# Filter out the features that aren't missing anything
dfm = df_missing_percentages[df_missing_percentages > 0].sort_values()
gdfm = gdf_missing_percentages[gdf_missing_percentages > 0].sort_values()

display(HTML(f"""
<div style="float: left; width: 50%;"><pre>{dfm}</pre></div>
<div style="float: right; width: 50%;"><pre>{gdfm}</pre></div>
"""))
# Out:
# <div style="float: left; width: 50%;"><pre>street_name                       0.000130
# street_direction                  0.000520
# beat_of_occurrence                0.000651
# injuries_unknown                  0.217947
# injuries_no_indication            0.217947
# injuries_reported_not_evident     0.217947
# injuries_non_incapacitating       0.217947
# injuries_incapacitating           0.217947
# injuries_fatal                    0.217947
# injuries_total                    0.217947
# most_severe_injury                0.219378
# rd_no                             0.572258
# latitude                          0.664771
# location                          0.664771
# longitude                         0.664771
# report_type                       2.884319
# hit_and_run_i                    68.776959
# lane_cnt                         74.105929
# intersection_related_i           77.092520
# crash_date_est_i                 92.472431
# not_right_of_way_i               95.358572
# statements_taken_i               97.820919
# photos_taken_i                   98.712355
# work_zone_i                      99.420976
# work_zone_type                   99.549402
# dooring_i                        99.690840
# workers_present_i                99.851145
# dtype: float64</pre></div>
# <div style="float: right; width: 50%;"><pre>street_name                       0.000130
# street_direction                  0.000520
# beat_of_occurrence                0.000651
# injuries_reported_not_evident     0.217947
# injuries_fatal                    0.217947
# injuries_total                    0.217947
# injuries_non_incapacitating       0.217947
# injuries_incapacitating           0.217947
# injuries_no_indication            0.217947
# injuries_unknown                  0.217947
# most_severe_injury                0.219378
# rd_no                             0.572258
# geometry                          0.664771
# latitude                          0.664771
# longitude                         0.664771
# report_type                       2.884319
# hit_and_run_i                    68.776959
# lane_cnt                         74.105929
# intersection_related_i           77.092520
# crash_date_est_i                 92.472431
# private_property_i               95.358572
# statements_taken_i               97.820919
# photos_taken_i                   98.712355
# work_zone_i                      99.420976
# work_zone_type                   99.549402
# dooring_i                        99.690840
# workers_present_i                99.851145
# dtype: float64</pre></div>

# %% [markdown]
# Several columns ending in _I appear to have significant missing data, which we'll address in the next step.
#
# We'll also be using the `describe()` function only on the dataframe, as GeoPandas no longer supports it. However, this shouldn't be a point of concern, considering we are working with the same dataset.

# %%
df.describe()
# Out:
#        posted_speed_limit      lane_cnt      street_no  beat_of_occurrence  \
# count       768535.000000  1.990050e+05  768535.000000       768530.000000
# mean            28.391139  1.333038e+01    3685.688306         1242.201924
# std              6.200848  2.961631e+03    2889.338175          705.390224
# min              0.000000  0.000000e+00       0.000000          111.000000
# 25%             30.000000  2.000000e+00    1244.000000          713.000000
# 50%             30.000000  2.000000e+00    3200.000000         1211.000000
# 75%             30.000000  4.000000e+00    5600.000000         1822.000000
# max             99.000000  1.191625e+06  451100.000000         6100.000000
#
#            num_units  injuries_total  injuries_fatal  injuries_incapacitating  \
# count  768535.000000   766860.000000   766860.000000            766860.000000
# mean        2.034717        0.188225        0.001193                 0.020147
# std         0.452438        0.563656        0.037457                 0.166358
# min         1.000000        0.000000        0.000000                 0.000000
# 25%         2.000000        0.000000        0.000000                 0.000000
# 50%         2.000000        0.000000        0.000000                 0.000000
# 75%         2.000000        0.000000        0.000000                 0.000000
# max        18.000000       21.000000        4.000000                10.000000
#
#        injuries_non_incapacitating  injuries_reported_not_evident  \
# count                766860.000000                  766860.000000
# mean                      0.106460                       0.060424
# std                       0.420662                       0.316222
# min                       0.000000                       0.000000
# 25%                       0.000000                       0.000000
# 50%                       0.000000                       0.000000
# 75%                       0.000000                       0.000000
# max                      21.000000                      15.000000
#
#        injuries_no_indication  injuries_unknown     crash_hour  \
# count           766860.000000          766860.0  768535.000000
# mean                 2.005057               0.0      13.209112
# std                  1.159794               0.0       5.563800
# min                  0.000000               0.0       0.000000
# 25%                  1.000000               0.0       9.000000
# 50%                  2.000000               0.0      14.000000
# 75%                  2.000000               0.0      17.000000
# max                 61.000000               0.0      23.000000
#
#        crash_day_of_week    crash_month       latitude      longitude
# count      768535.000000  768535.000000  763426.000000  763426.000000
# mean            4.123882       6.649006      41.854862     -87.673646
# std             1.980332       3.365313       0.329216       0.668228
# min             1.000000       1.000000       0.000000     -87.936193
# 25%             2.000000       4.000000      41.782297     -87.721629
# 50%             4.000000       7.000000      41.874654     -87.673982
# 75%             6.000000       9.000000      41.924259     -87.633227
# max             7.000000      12.000000      42.022780       0.000000

# %%
import json

# Filter potential 'categorical' columns with less than 100 unique values
filtered_columns = df.columns[df.apply(lambda col: col.dtype == 'object' and len(col.unique()) < 100)].tolist()

# Store the unique values for each column in a dictionary
unique_values_by_column = {col: df[col].sort_values().unique().tolist() for col in filtered_columns}

# Save the dictionary to an output file
with open('df_unique_values_by_column.json', 'w') as f:
    json.dump(unique_values_by_column, f, indent=4)

# %% [markdown]
# - The unique categorical values have been stored in a file to for visibility purposes.
# - A threshold of 100 unique values; columns exceeding this count are likely not categorical in nature, for example, street names.
#
# Upon a brief examination,
# - Many values have missing entries (`NaN`).
# - The columns `PRIM_CONTRIBUTORY_CAUSE` and `SEC_CONTRIBUTORY_CAUSE` have the same values.
# - Columns ending in `_I` appear to be boolean in nature.
# - The remaining columns display varied values with little to no similarity.

# %% [markdown]
# We'll check the latitudinal and longitudinal values for any points outside the limits of Chicago. Based on the missing values check, these values correspond to the location/geometry column.

# %%
long_min = -87.9401
lat_min = 41.6445
long_max = -87.5241
lat_max = 42.0230

# We're updating the datatypes in Part 2 but we'll do it here just for the comparisons
df[['latitude', 'longitude']] = df[['latitude', 'longitude']].apply(pd.to_numeric, errors='coerce')
gdf[['latitude', 'longitude']] = gdf[['latitude', 'longitude']].apply(pd.to_numeric, errors='coerce')

# Get any points that are outside of the boundaries of the city.
out_of_bounds_df = df[(df['latitude'] < lat_min) | (df['latitude'] > lat_max) | (df['longitude'] < long_min) | (df['longitude'] > long_max)]
out_of_bounds_gdf = gdf[(gdf['latitude'] < lat_min) | (gdf['latitude'] > lat_max) | (gdf['longitude'] < long_min) | (gdf['longitude'] > long_max)]

# Count the number of points outside
out_of_bounds_df.shape[0], out_of_bounds_gdf.shape[0]
# Out:
# (44, 44)

# %% [markdown]
# ### Cleaning the Data
#
# Having identified underlying issues like missing values, we'll address them to guarantee consistent and reliable analyses. For efficiency, we'll make adjustments directly to the dataframe (using `inplace` if applicable). We won't need the original, and our source remains unaltered on the cloud.

# %% [markdown]
# We will start by removing any points outside the boundaries of the city.

# %%
# We'll apply them separately in case they are in different indices.
df.drop(index=out_of_bounds_df.index, inplace=True)
gdf.drop(index=out_of_bounds_gdf.index, inplace=True)

df.shape, gdf.shape
# Out:
# ((768491, 49), (768491, 49))

# %% [markdown]
# Next, we'll omit the columns `CRASH_REPORT_ID` and `RD_NO` from our analysis. The former is relevant only when interfacing with supplementary datasets, and the latter merely represents a report identifier.

# %%
df.drop(columns=['crash_record_id', 'rd_no'], inplace=True)
gdf.drop(columns=['crash_record_id', 'rd_no'], inplace=True)

# %% [markdown]
# After evaluating the column types and their respective values above, we have determine:
#
# - For the majority of columns, particularly those that detail specific incident attributes, we're choosing not to alter values to maintain the integrity and accuracy of our data.
#
# - Columns like LANE_CNT and BEAT_OF_OCCURRENCE present a unique challenge. While there's a theoretical possibility of programmatic modification, the nature of the data combined with the dataset's large size makes such an endeavor both challenging and potentially infeasible.
#
# - On the other hand, there are columns, such as WORK_ZONE_TYPE, where we can make modifications. However, we're deciding against it as we plan to discard this shortly.
#
# In essence, given the reasons stated above, we won't be filling any missing values. However, we will be removing columns where more than 3% of the dataset is missing. It's evident that the columns vital for our domain-specific questions don't exceed this threshold. In other words, removing the rows won't have any negative consequences.

# %%
columns_to_drop_df = df_missing_percentages[df_missing_percentages > 3].index
columns_to_drop_gdf = gdf_missing_percentages[gdf_missing_percentages > 3].index

df.drop(columns=columns_to_drop_df, inplace=True)
gdf.drop(columns=columns_to_drop_gdf, inplace=True)

# %% [markdown]
# We are keeping the remaining columns in case we may want to expand our analysis in the future.

# %% [markdown]
# With the modifications in place, we can remove the rows with `NaN` values as they aren't beneficial. By using `shape`, we can see how much of the dataset has changed.

# %%
df.dropna(inplace=True)
gdf.dropna(inplace=True)

df.shape, gdf.shape
# Out:
# ((739675, 36), (739675, 36))

# %% [markdown]
# Furthermore, we'll modify the categorical values for the contributory causes to shorten them for readability.

# %%
labels = {
    "ANIMAL": "Animal",
    "BICYCLE ADVANCING LEGALLY ON RED LIGHT": "Bicycle on Red",
    "CELL PHONE USE OTHER THAN TEXTING": "Cell Phone Use",
    "DISREGARDING OTHER TRAFFIC SIGNS": "Ignored Signs",
    "DISREGARDING ROAD MARKINGS": "Ignored Markings",
    "DISREGARDING STOP SIGN": "Ignored Stop",
    "DISREGARDING TRAFFIC SIGNALS": "Ignored Signals",
    "DISREGARDING YIELD SIGN": "Ignored Yield",
    "DISTRACTION - FROM INSIDE VEHICLE": "Inside Distraction",
    "DISTRACTION - FROM OUTSIDE VEHICLE": "Outside Distraction",
    "DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)": "Electronics Distraction",
    "DRIVING ON WRONG SIDE/WRONG WAY": "Wrong Side",
    "DRIVING SKILLS/KNOWLEDGE/EXPERIENCE": "Poor Skills",
    "EQUIPMENT - VEHICLE CONDITION": "Vehicle Issue",
    "EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST": "Evasive Action",
    "EXCEEDING AUTHORIZED SPEED LIMIT": "Over Limit",
    "EXCEEDING SAFE SPEED FOR CONDITIONS": "Unsafe Speed",
    "FAILING TO REDUCE SPEED TO AVOID CRASH": "No Speed Reduction",
    "FAILING TO YIELD RIGHT-OF-WAY": "Failed to Yield",
    "FOLLOWING TOO CLOSELY": "Tailgating",
    "HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)": "Drinking",
    "IMPROPER BACKING": "Bad Backing",
    "IMPROPER LANE USAGE": "Wrong Lane",
    "IMPROPER OVERTAKING/PASSING": "Unsafe Overtake",
    "IMPROPER TURNING/NO SIGNAL": "No Turn Signal",
    "MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT": "Motorcycle on Red",
    "NOT APPLICABLE": "N/A",
    "OBSTRUCTED CROSSWALKS": "Obstructed Walk",
    "OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER": "Reckless Driving",
    "PASSING STOPPED SCHOOL BUS": "Passed School Bus",
    "PHYSICAL CONDITION OF DRIVER": "Driver Condition",
    "RELATED TO BUS STOP": "Bus Stop Related",
    "ROAD CONSTRUCTION/MAINTENANCE": "Road Construction",
    "ROAD ENGINEERING/SURFACE/MARKING DEFECTS": "Road Defects",
    "TEXTING": "Texting",
    "TURNING RIGHT ON RED": "Right on Red",
    "UNABLE TO DETERMINE": "Unknown",
    "UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)": "DUI",
    "VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)": "Vision Blocked",
    "WEATHER": "Weather"
}

df['prim_contributory_cause'].replace(labels, inplace=True)
df['sec_contributory_cause'].replace(labels, inplace=True)

# %% [markdown]
# With the modifications in place, we'll export the results to files for use for Part 2. Additionally, a backup of these changes will be saved in the cloud for convenient access in Colab.
#
# - The `GeoDataFrame` will be saved to the binary Feather format to enhance efficiency and speed up subsequent data loading.

# %%
# Use the same filename across both files
shared_fn = 'Traffic Crashes (Modified)'

df.to_csv(shared_fn + '.csv')
gdf.to_feather(shared_fn + '.feather')
